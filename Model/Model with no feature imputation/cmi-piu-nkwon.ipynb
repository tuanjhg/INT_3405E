# %% [markdown]
# <p style="background-color:#4CAF50; font-family:'Arial', sans-serif; color:#FFFFFF; font-size:120%; text-align:center; border: 2px solid #FFFFFF; border-radius:20px; padding: 15px; box-shadow: 2px 2px 4px #888888;">
#     Chile Mind Institute | NKwon
# </p>

# %%
# Trần Bình Minh , Khổng Mạnh Tuấn , Lê Quyết Chiến

# %%
import numpy as np
import polars as pl
import pandas as pd
from sklearn.base import clone
from copy import deepcopy
import optuna
from scipy.optimize import minimize
import os
from scipy.stats import mode

import re
from colorama import Fore, Style

from tqdm import tqdm
from IPython.display import clear_output
from concurrent.futures import ThreadPoolExecutor

import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

import lightgbm as lgb
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.model_selection import *
from sklearn.metrics import *

seed_list = [42, 2024, 1234]
n_splits = 5

# %% [markdown]
# <p style="background-color:#4CAF50; font-family:'Arial', sans-serif; color:#FFFFFF; font-size:120%; text-align:center; border: 2px solid #FFFFFF; border-radius:20px; padding: 15px; box-shadow: 2px 2px 4px #888888;">
#   Basic Progress
# </p>

# %%
# %%time

def process_file(filename, dirname):
    df = pd.read_parquet(os.path.join(dirname, filename, 'part-0.parquet'))
    df.drop('step', axis=1, inplace=True)
    return df.describe().values.reshape(-1), filename.split('=')[1]

def load_time_series(dirname) -> pd.DataFrame:
    ids = os.listdir(dirname)
    
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(lambda fname: process_file(fname, dirname), ids), total=len(ids)))
    
    stats, indexes = zip(*results)
    
    df = pd.DataFrame(stats, columns=[f"Stat_{i}" for i in range(len(stats[0]))])
    df['id'] = indexes
    
    return df

train = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/train.csv')
test = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/test.csv')
sample = pd.read_csv('/kaggle/input/child-mind-institute-problematic-internet-use/sample_submission.csv')

train_ts = load_time_series("/kaggle/input/child-mind-institute-problematic-internet-use/series_train.parquet")
test_ts = load_time_series("/kaggle/input/child-mind-institute-problematic-internet-use/series_test.parquet")
time_series_cols = train_ts.columns.tolist()
time_series_cols.remove("id")

train = pd.merge(train, train_ts, how="left", on='id')
test = pd.merge(test, test_ts, how="left", on='id')

train = train.drop('id', axis=1)
test = test.drop('id', axis=1)

featuresCols = ['Basic_Demos-Enroll_Season', 'Basic_Demos-Age', 'Basic_Demos-Sex',
                'CGAS-Season', 'CGAS-CGAS_Score', 'Physical-Season', 'Physical-BMI',
                'Physical-Height', 'Physical-Weight', 'Physical-Waist_Circumference',
                'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP',
                'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage',
                'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec',
                'FGC-Season', 'FGC-FGC_CU', 'FGC-FGC_CU_Zone', 'FGC-FGC_GSND',
                'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'FGC-FGC_PU',
                'FGC-FGC_PU_Zone', 'FGC-FGC_SRL', 'FGC-FGC_SRL_Zone', 'FGC-FGC_SRR',
                'FGC-FGC_SRR_Zone', 'FGC-FGC_TL', 'FGC-FGC_TL_Zone', 'BIA-Season',
                'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI',
                'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM',
                'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num',
                'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM',
                'BIA-BIA_TBW', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total', 'PAQ_C-Season',
                'PAQ_C-PAQ_C_Total', 'SDS-Season', 'SDS-SDS_Total_Raw',
                'SDS-SDS_Total_T', 'PreInt_EduHx-Season',
                'PreInt_EduHx-computerinternet_hoursday', 'sii']

featuresCols += time_series_cols

train = train[featuresCols]
train = train.dropna(subset='sii')

cat_c = ['Basic_Demos-Enroll_Season', 'CGAS-Season', 'Physical-Season', 'Fitness_Endurance-Season', 
          'FGC-Season', 'BIA-Season', 'PAQ_A-Season', 'PAQ_C-Season', 'SDS-Season', 'PreInt_EduHx-Season']

def update(df):
    for c in cat_c: 
        df[c] = df[c].fillna('Missing')
        df[c] = df[c].astype('category')
    return df
        
train = update(train)
test = update(test)

def create_mapping(column, dataset):
    unique_values = dataset[column].unique()
    return {value: idx for idx, value in enumerate(unique_values)}

for col in cat_c:
    mapping_train = create_mapping(col, train)
    
    train[col] = train[col].replace(mapping_train).astype(int)
    test[col] = test[col].replace(mapping_train).astype(int)

print(f'Train Shape : {train.shape} || Test Shape : {test.shape}')
# Out:
# 100%|██████████| 996/996 [01:32<00:00, 10.75it/s]
# 100%|██████████| 2/2 [00:00<00:00,  8.68it/s]
# Train Shape : (2736, 155) || Test Shape : (20, 154)
# CPU times: user 4min 2s, sys: 36.1 s, total: 4min 38s
# Wall time: 1min 33s

# %%
# %%time

train.head()
# Out:
# CPU times: user 289 µs, sys: 1.05 ms, total: 1.34 ms
# Wall time: 581 µs
#    Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  CGAS-Season  \
# 0                          0                5                0            0
# 1                          1                9                0            1
# 2                          1               10                1            2
# 3                          2                9                0            2
# 5                          3               13                1            0
#
#    CGAS-CGAS_Score  Physical-Season  Physical-BMI  Physical-Height  \
# 0             51.0                0     16.877316             46.0
# 1              NaN                0     14.035590             48.0
# 2             71.0                0     16.648696             56.5
# 3             71.0                1     18.292347             56.0
# 5             50.0                1     22.279952             59.5
#
#    Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0             50.8                           NaN                    NaN
# 1             46.0                          22.0                   75.0
# 2             75.6                           NaN                   65.0
# 3             81.6                           NaN                   60.0
# 5            112.2                           NaN                   60.0
#
#    Physical-HeartRate  Physical-Systolic_BP  Fitness_Endurance-Season  \
# 0                 NaN                   NaN                         0
# 1                70.0                 122.0                         0
# 2                94.0                 117.0                         1
# 3                97.0                 117.0                         2
# 5                73.0                 102.0                         0
#
#    Fitness_Endurance-Max_Stage  Fitness_Endurance-Time_Mins  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          5.0                          7.0
# 3                          6.0                          9.0
# 5                          NaN                          NaN
#
#    Fitness_Endurance-Time_Sec  FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# 0                         NaN           0         0.0              0.0
# 1                         NaN           0         3.0              0.0
# 2                        33.0           0        20.0              1.0
# 3                        37.0           1        18.0              1.0
# 5                         NaN           1        12.0              0.0
#
#    FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  \
# 0           NaN                NaN          NaN               NaN         0.0
# 1           NaN                NaN          NaN               NaN         5.0
# 2          10.2                1.0         14.7               2.0         7.0
# 3           NaN                NaN          NaN               NaN         5.0
# 5          16.5                2.0         17.9               2.0         6.0
#
#    FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# 0              0.0          7.0               0.0          6.0
# 1              0.0         11.0               1.0         11.0
# 2              1.0         10.0               1.0         10.0
# 3              0.0          7.0               0.0          7.0
# 5              0.0         10.0               1.0         11.0
#
#    FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone  BIA-Season  \
# 0               0.0         6.0              1.0           0
# 1               1.0         3.0              0.0           1
# 2               1.0         5.0              0.0           2
# 3               0.0         7.0              1.0           3
# 5               1.0         8.0              0.0           3
#
#    BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                         2.0      2.66855      16.8792      932.498
# 1                         2.0      2.57949      14.0371      936.656
# 2                         NaN          NaN          NaN          NaN
# 3                         3.0      3.84191      18.2943     1131.430
# 5                         2.0      4.33036      30.1865     1330.970
#
#    BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0      1492.00      8.25598      41.5862       13.8177      3.06143
# 1      1498.65      6.01993      42.0291       12.8254      1.21172
# 2          NaN          NaN          NaN           NaN          NaN
# 3      1923.44     15.59250      62.7757       14.0740      4.22033
# 5      1996.45     30.21240      84.0285       16.6877     13.49880
#
#    BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# 0      9.21377                1.0      24.4349      8.89536      38.9177
# 1      3.97085                1.0      21.0352     14.97400      39.4497
# 2          NaN                NaN          NaN          NaN          NaN
# 3     18.82430                2.0      30.4041     16.77900      58.9338
# 5     67.97150                2.0      32.9141     20.90200      79.6982
#
#    BIA-BIA_SMM  BIA-BIA_TBW  PAQ_A-Season  PAQ_A-PAQ_A_Total  PAQ_C-Season  \
# 0      19.5413      32.6909             0                NaN             0
# 1      15.4107      27.0552             0                NaN             1
# 2          NaN          NaN             0                NaN             2
# 3      26.4798      45.9966             0                NaN             3
# 5      35.3804      63.1265             0                NaN             4
#
#    PAQ_C-PAQ_C_Total  SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                NaN           0                NaN              NaN
# 1              2.340           1               46.0             64.0
# 2              2.170           1               38.0             54.0
# 3              2.451           2               31.0             45.0
# 5              4.110           2               40.0             56.0
#
#    PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday  sii    Stat_0  \
# 0                    0                                     3.0  2.0       NaN
# 1                    1                                     0.0  0.0       NaN
# 2                    1                                     2.0  0.0       NaN
# 3                    2                                     0.0  1.0   43330.0
# 5                    3                                     0.0  1.0  396396.0
#
#      Stat_1    Stat_2    Stat_3    Stat_4    Stat_5    Stat_6    Stat_7  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3   43330.0   43330.0   43330.0   43330.0   43330.0   43330.0   43330.0
# 5  396396.0  396396.0  396396.0  396396.0  396396.0  396396.0  396396.0
#
#      Stat_8    Stat_9   Stat_10   Stat_11   Stat_12   Stat_13   Stat_14  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3   43330.0   43330.0   43330.0   43330.0 -0.316384  0.016009 -0.167890
# 5  396396.0  396396.0  396396.0  396396.0 -0.004272  0.016859 -0.631731
#
#     Stat_15    Stat_16   Stat_17    Stat_18      Stat_19       Stat_20  \
# 0       NaN        NaN       NaN        NaN          NaN           NaN
# 1       NaN        NaN       NaN        NaN          NaN           NaN
# 2       NaN        NaN       NaN        NaN          NaN           NaN
# 3  0.047388 -10.580416  0.000000  42.296310  4053.579102  5.046215e+13
# 5  0.011926 -55.630768  0.655708  16.771982  3838.189453  4.321212e+13
#
#     Stat_21  Stat_22    Stat_23   Stat_24   Stat_25   Stat_26   Stat_27  \
# 0       NaN      NaN        NaN       NaN       NaN       NaN       NaN
# 1       NaN      NaN        NaN       NaN       NaN       NaN       NaN
# 2       NaN      NaN        NaN       NaN       NaN       NaN       NaN
# 3  4.470182      3.0  53.201683  0.453665  0.502702  0.585710  0.106351
# 5  3.909848      3.0  79.435593  0.351545  0.303812  0.623476  0.024331
#
#      Stat_28   Stat_29     Stat_30     Stat_31       Stat_32   Stat_33  \
# 0        NaN       NaN         NaN         NaN           NaN       NaN
# 1        NaN       NaN         NaN         NaN           NaN       NaN
# 2        NaN       NaN         NaN         NaN           NaN       NaN
# 3  42.947170  0.000000  208.168976  112.404045  1.942842e+13  1.931421
# 5  50.303635  0.468723   95.327438  155.573868  2.497264e+13  1.946892
#
#    Stat_34    Stat_35   Stat_36   Stat_37   Stat_38  Stat_39    Stat_40  \
# 0      NaN        NaN       NaN       NaN       NaN      NaN        NaN
# 1      NaN        NaN       NaN       NaN       NaN      NaN        NaN
# 2      NaN        NaN       NaN       NaN       NaN      NaN        NaN
# 3      0.0  14.244914 -1.746094 -2.905339 -1.048372      0.0 -89.833092
# 5      0.0   6.634319 -1.038711 -1.522690 -1.018787      0.0 -88.761833
#
#    Stat_41  Stat_42      Stat_43       Stat_44  Stat_45  Stat_46  Stat_47  \
# 0      NaN      NaN          NaN           NaN      NaN      NaN      NaN
# 1      NaN      NaN          NaN           NaN      NaN      NaN      NaN
# 2      NaN      NaN          NaN           NaN      NaN      NaN      NaN
# 3      0.0      0.0  3824.000000  5.500000e+10      1.0      3.0     41.0
# 5      0.0      0.0  3098.166748  0.000000e+00      1.0      3.0     68.0
#
#     Stat_48   Stat_49   Stat_50   Stat_51    Stat_52  Stat_53   Stat_54  \
# 0       NaN       NaN       NaN       NaN        NaN      NaN       NaN
# 1       NaN       NaN       NaN       NaN        NaN      NaN       NaN
# 2       NaN       NaN       NaN       NaN        NaN      NaN       NaN
# 3 -0.684180 -0.309863 -0.649974  0.006432 -41.541863      0.0  2.392969
# 5 -0.052803 -0.044517 -1.009344  0.008622 -88.386049      0.0  0.500000
#
#        Stat_55       Stat_56  Stat_57  Stat_58  Stat_59   Stat_60   Stat_61  \
# 0          NaN           NaN      NaN      NaN      NaN       NaN       NaN
# 1          NaN           NaN      NaN      NaN      NaN       NaN       NaN
# 2          NaN           NaN      NaN      NaN      NaN       NaN       NaN
# 3  4028.666748  3.689000e+13      3.0      3.0     42.0 -0.366849  0.024974
# 5  3747.000000  2.154000e+13      2.0      3.0     74.0 -0.020622 -0.028179
#
#     Stat_62   Stat_63    Stat_64  Stat_65   Stat_66  Stat_67       Stat_68  \
# 0       NaN       NaN        NaN      NaN       NaN      NaN           NaN
# 1       NaN       NaN        NaN      NaN       NaN      NaN           NaN
# 2       NaN       NaN        NaN      NaN       NaN      NaN           NaN
# 3 -0.245378  0.023637 -15.086617      0.0  6.926828   4070.0  5.347750e+13
# 5 -1.007728  0.009831 -86.119919      1.0  0.879005   3812.0  4.331000e+13
#
#    Stat_69  Stat_70  Stat_71   Stat_72   Stat_73   Stat_74   Stat_75  \
# 0      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 1      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 2      NaN      NaN      NaN       NaN       NaN       NaN       NaN
# 3      5.0      3.0     50.0 -0.010677  0.400677  0.204727  0.041420
# 5      4.0      3.0     79.0 -0.019081  0.020307 -0.294459  0.010668
#
#      Stat_76  Stat_77    Stat_78      Stat_79       Stat_80  Stat_81  Stat_82  \
# 0        NaN      NaN        NaN          NaN           NaN      NaN      NaN
# 1        NaN      NaN        NaN          NaN           NaN      NaN      NaN
# 2        NaN      NaN        NaN          NaN           NaN      NaN      NaN
# 3  12.220764      0.0  15.000000  4147.000000  6.640875e+13      6.0      3.0
# 5 -17.483364      1.0   6.141348  3951.187561  6.485500e+13      6.0      3.0
#
#    Stat_83   Stat_84   Stat_85   Stat_86   Stat_87    Stat_88  Stat_89  \
# 0      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 1      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 2      NaN       NaN       NaN       NaN       NaN        NaN      NaN
# 3     53.0  1.507865  1.666354  1.546979  4.004276  89.751656      0.0
# 5     85.0  1.034351  1.946303  1.146284  2.952888  89.476036      1.0
#
#        Stat_90  Stat_91       Stat_92  Stat_93  Stat_94  Stat_95
# 0          NaN      NaN           NaN      NaN      NaN      NaN
# 1          NaN      NaN           NaN      NaN      NaN      NaN
# 2          NaN      NaN           NaN      NaN      NaN      NaN
# 3  2633.250000   4188.5  8.611000e+13      7.0      3.0     85.0
# 5  2597.800049   4175.0  8.639500e+13      7.0      3.0     91.0

# %%
# %%time

test.head()
# Out:
# CPU times: user 250 µs, sys: 37 µs, total: 287 µs
# Wall time: 315 µs
#    Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  CGAS-Season  \
# 0                          0                5                0            0
# 1                          1                9                0            1
# 2                          1               10                1            2
# 3                          2                9                0            2
# 4                          3               18                1            3
#
#    CGAS-CGAS_Score  Physical-Season  Physical-BMI  Physical-Height  \
# 0             51.0                0     16.877316             46.0
# 1              NaN                0     14.035590             48.0
# 2             71.0                0     16.648696             56.5
# 3             71.0                1     18.292347             56.0
# 4              NaN                2           NaN              NaN
#
#    Physical-Weight  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0             50.8                           NaN                    NaN
# 1             46.0                          22.0                   75.0
# 2             75.6                           NaN                   65.0
# 3             81.6                           NaN                   60.0
# 4              NaN                           NaN                    NaN
#
#    Physical-HeartRate  Physical-Systolic_BP  Fitness_Endurance-Season  \
# 0                 NaN                   NaN                         0
# 1                70.0                 122.0                         0
# 2                94.0                 117.0                         1
# 3                97.0                 117.0                         2
# 4                 NaN                   NaN                         0
#
#    Fitness_Endurance-Max_Stage  Fitness_Endurance-Time_Mins  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          5.0                          7.0
# 3                          6.0                          9.0
# 4                          NaN                          NaN
#
#    Fitness_Endurance-Time_Sec  FGC-Season  FGC-FGC_CU  FGC-FGC_CU_Zone  \
# 0                         NaN           0         0.0              0.0
# 1                         NaN           0         3.0              0.0
# 2                        33.0           0        20.0              1.0
# 3                        37.0           1        18.0              1.0
# 4                         NaN           4         NaN              NaN
#
#    FGC-FGC_GSND  FGC-FGC_GSND_Zone  FGC-FGC_GSD  FGC-FGC_GSD_Zone  FGC-FGC_PU  \
# 0           NaN                NaN          NaN               NaN         0.0
# 1           NaN                NaN          NaN               NaN         5.0
# 2          10.2                1.0         14.7               2.0         7.0
# 3           NaN                NaN          NaN               NaN         5.0
# 4           NaN                NaN          NaN               NaN         NaN
#
#    FGC-FGC_PU_Zone  FGC-FGC_SRL  FGC-FGC_SRL_Zone  FGC-FGC_SRR  \
# 0              0.0          7.0               0.0          6.0
# 1              0.0         11.0               1.0         11.0
# 2              1.0         10.0               1.0         10.0
# 3              0.0          7.0               0.0          7.0
# 4              NaN          NaN               NaN          NaN
#
#    FGC-FGC_SRR_Zone  FGC-FGC_TL  FGC-FGC_TL_Zone  BIA-Season  \
# 0               0.0         6.0              1.0           0
# 1               1.0         3.0              0.0           1
# 2               1.0         5.0              0.0           2
# 3               0.0         7.0              1.0           3
# 4               NaN         NaN              NaN           2
#
#    BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                         2.0      2.66855      16.8792      932.498
# 1                         2.0      2.57949      14.0371      936.656
# 2                         NaN          NaN          NaN          NaN
# 3                         3.0      3.84191      18.2943     1131.430
# 4                         NaN          NaN          NaN          NaN
#
#    BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0      1492.00      8.25598      41.5862       13.8177      3.06143
# 1      1498.65      6.01993      42.0291       12.8254      1.21172
# 2          NaN          NaN          NaN           NaN          NaN
# 3      1923.44     15.59250      62.7757       14.0740      4.22033
# 4          NaN          NaN          NaN           NaN          NaN
#
#    BIA-BIA_Fat  BIA-BIA_Frame_num  BIA-BIA_ICW  BIA-BIA_LDM  BIA-BIA_LST  \
# 0      9.21377                1.0      24.4349      8.89536      38.9177
# 1      3.97085                1.0      21.0352     14.97400      39.4497
# 2          NaN                NaN          NaN          NaN          NaN
# 3     18.82430                2.0      30.4041     16.77900      58.9338
# 4          NaN                NaN          NaN          NaN          NaN
#
#    BIA-BIA_SMM  BIA-BIA_TBW  PAQ_A-Season  PAQ_A-PAQ_A_Total  PAQ_C-Season  \
# 0      19.5413      32.6909             0                NaN             0
# 1      15.4107      27.0552             0                NaN             1
# 2          NaN          NaN             0                NaN             2
# 3      26.4798      45.9966             0                NaN             3
# 4          NaN          NaN             1               1.04             0
#
#    PAQ_C-PAQ_C_Total  SDS-Season  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                NaN           0                NaN              NaN
# 1              2.340           1               46.0             64.0
# 2              2.170           1               38.0             54.0
# 3              2.451           2               31.0             45.0
# 4                NaN           0                NaN              NaN
#
#    PreInt_EduHx-Season  PreInt_EduHx-computerinternet_hoursday   Stat_0  \
# 0                    0                                     3.0      NaN
# 1                    1                                     0.0      NaN
# 2                    1                                     2.0      NaN
# 3                    2                                     0.0  43330.0
# 4                    4                                     NaN      NaN
#
#     Stat_1   Stat_2   Stat_3   Stat_4   Stat_5   Stat_6   Stat_7   Stat_8  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3  43330.0  43330.0  43330.0  43330.0  43330.0  43330.0  43330.0  43330.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#     Stat_9  Stat_10  Stat_11   Stat_12   Stat_13  Stat_14   Stat_15  \
# 0      NaN      NaN      NaN       NaN       NaN      NaN       NaN
# 1      NaN      NaN      NaN       NaN       NaN      NaN       NaN
# 2      NaN      NaN      NaN       NaN       NaN      NaN       NaN
# 3  43330.0  43330.0  43330.0 -0.316384  0.016009 -0.16789  0.047388
# 4      NaN      NaN      NaN       NaN       NaN      NaN       NaN
#
#      Stat_16  Stat_17   Stat_18      Stat_19       Stat_20   Stat_21  Stat_22  \
# 0        NaN      NaN       NaN          NaN           NaN       NaN      NaN
# 1        NaN      NaN       NaN          NaN           NaN       NaN      NaN
# 2        NaN      NaN       NaN          NaN           NaN       NaN      NaN
# 3 -10.580416      0.0  42.29631  4053.579102  5.046215e+13  4.470182      3.0
# 4        NaN      NaN       NaN          NaN           NaN       NaN      NaN
#
#      Stat_23   Stat_24   Stat_25  Stat_26   Stat_27   Stat_28  Stat_29  \
# 0        NaN       NaN       NaN      NaN       NaN       NaN      NaN
# 1        NaN       NaN       NaN      NaN       NaN       NaN      NaN
# 2        NaN       NaN       NaN      NaN       NaN       NaN      NaN
# 3  53.201683  0.453665  0.502702  0.58571  0.106351  42.94717      0.0
# 4        NaN       NaN       NaN      NaN       NaN       NaN      NaN
#
#       Stat_30     Stat_31       Stat_32   Stat_33  Stat_34    Stat_35  \
# 0         NaN         NaN           NaN       NaN      NaN        NaN
# 1         NaN         NaN           NaN       NaN      NaN        NaN
# 2         NaN         NaN           NaN       NaN      NaN        NaN
# 3  208.168976  112.404045  1.942842e+13  1.931421      0.0  14.244914
# 4         NaN         NaN           NaN       NaN      NaN        NaN
#
#     Stat_36   Stat_37   Stat_38  Stat_39    Stat_40  Stat_41  Stat_42  \
# 0       NaN       NaN       NaN      NaN        NaN      NaN      NaN
# 1       NaN       NaN       NaN      NaN        NaN      NaN      NaN
# 2       NaN       NaN       NaN      NaN        NaN      NaN      NaN
# 3 -1.746094 -2.905339 -1.048372      0.0 -89.833092      0.0      0.0
# 4       NaN       NaN       NaN      NaN        NaN      NaN      NaN
#
#    Stat_43       Stat_44  Stat_45  Stat_46  Stat_47  Stat_48   Stat_49  \
# 0      NaN           NaN      NaN      NaN      NaN      NaN       NaN
# 1      NaN           NaN      NaN      NaN      NaN      NaN       NaN
# 2      NaN           NaN      NaN      NaN      NaN      NaN       NaN
# 3   3824.0  5.500000e+10      1.0      3.0     41.0 -0.68418 -0.309863
# 4      NaN           NaN      NaN      NaN      NaN      NaN       NaN
#
#     Stat_50   Stat_51    Stat_52  Stat_53   Stat_54      Stat_55  \
# 0       NaN       NaN        NaN      NaN       NaN          NaN
# 1       NaN       NaN        NaN      NaN       NaN          NaN
# 2       NaN       NaN        NaN      NaN       NaN          NaN
# 3 -0.649974  0.006432 -41.541863      0.0  2.392969  4028.666748
# 4       NaN       NaN        NaN      NaN       NaN          NaN
#
#         Stat_56  Stat_57  Stat_58  Stat_59   Stat_60   Stat_61   Stat_62  \
# 0           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 1           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 2           NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 3  3.689000e+13      3.0      3.0     42.0 -0.366849  0.024974 -0.245378
# 4           NaN      NaN      NaN      NaN       NaN       NaN       NaN
#
#     Stat_63    Stat_64  Stat_65   Stat_66  Stat_67       Stat_68  Stat_69  \
# 0       NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 1       NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 2       NaN        NaN      NaN       NaN      NaN           NaN      NaN
# 3  0.023637 -15.086617      0.0  6.926828   4070.0  5.347750e+13      5.0
# 4       NaN        NaN      NaN       NaN      NaN           NaN      NaN
#
#    Stat_70  Stat_71   Stat_72   Stat_73   Stat_74  Stat_75    Stat_76  \
# 0      NaN      NaN       NaN       NaN       NaN      NaN        NaN
# 1      NaN      NaN       NaN       NaN       NaN      NaN        NaN
# 2      NaN      NaN       NaN       NaN       NaN      NaN        NaN
# 3      3.0     50.0 -0.010677  0.400677  0.204727  0.04142  12.220764
# 4      NaN      NaN       NaN       NaN       NaN      NaN        NaN
#
#    Stat_77  Stat_78  Stat_79       Stat_80  Stat_81  Stat_82  Stat_83  \
# 0      NaN      NaN      NaN           NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN           NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN           NaN      NaN      NaN      NaN
# 3      0.0     15.0   4147.0  6.640875e+13      6.0      3.0     53.0
# 4      NaN      NaN      NaN           NaN      NaN      NaN      NaN
#
#     Stat_84   Stat_85   Stat_86   Stat_87    Stat_88  Stat_89  Stat_90  \
# 0       NaN       NaN       NaN       NaN        NaN      NaN      NaN
# 1       NaN       NaN       NaN       NaN        NaN      NaN      NaN
# 2       NaN       NaN       NaN       NaN        NaN      NaN      NaN
# 3  1.507865  1.666354  1.546979  4.004276  89.751656      0.0  2633.25
# 4       NaN       NaN       NaN       NaN        NaN      NaN      NaN
#
#    Stat_91       Stat_92  Stat_93  Stat_94  Stat_95
# 0      NaN           NaN      NaN      NaN      NaN
# 1      NaN           NaN      NaN      NaN      NaN
# 2      NaN           NaN      NaN      NaN      NaN
# 3   4188.5  8.611000e+13      7.0      3.0     85.0
# 4      NaN           NaN      NaN      NaN      NaN

# %% [markdown]
# <p style="background-color:#4CAF50; font-family:'Arial', sans-serif; color:#FFFFFF; font-size:120%; text-align:center; border: 2px solid #FFFFFF; border-radius:20px; padding: 15px; box-shadow: 2px 2px 4px #888888;">
#  Modeling
# </p>

# %%
# %%time

def quadratic_weighted_kappa(y_true, y_pred):
    return cohen_kappa_score(y_true, y_pred, weights='quadratic')

def threshold_Rounder(oof_non_rounded, thresholds):
    return np.where(oof_non_rounded < thresholds[0], 0,
                    np.where(oof_non_rounded < thresholds[1], 1,
                             np.where(oof_non_rounded < thresholds[2], 2, 3)))

def evaluate_predictions(thresholds, y_true, oof_non_rounded):
    rounded_p = threshold_Rounder(oof_non_rounded, thresholds)
    return -quadratic_weighted_kappa(y_true, rounded_p)

X = train.drop(['sii'], axis=1)
y = train['sii']

def TrainML(model_class, test_data, seed_list):

    SKF = StratifiedKFold(n_splits=n_splits, shuffle=False,)
    
    train_S = []
    test_S = []
    
    oof_non_rounded = np.zeros(len(y), dtype=float) 
    oof_rounded = np.zeros(len(y), dtype=int) 
    test_preds = np.zeros((len(test_data), n_splits))

    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        
        random_seed = np.random.choice(seed_list)
        
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]

        model = clone(model_class)
        if hasattr(model, 'random_state'):
            model.set_params(random_state=random_seed)

        model.fit(X_train, y_train)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        train_kappa = quadratic_weighted_kappa(y_train, y_train_pred.round(0).astype(int))
        val_kappa = quadratic_weighted_kappa(y_val, y_val_pred_rounded)

        train_S.append(train_kappa)
        test_S.append(val_kappa)
        
        test_preds[:, fold] = model.predict(test_data)
        
        print(f"Fold {fold+1} - Train QWK: {train_kappa:.4f}, Validation QWK: {val_kappa:.4f}")
        clear_output(wait=True)

    print(f"Train : {np.mean(train_S):.4f}")
    print(f"Validation : {np.mean(test_S):.4f}")

    KappaOPtimizer = minimize(evaluate_predictions,
                              x0=[0.5, 1.5, 2.5], args=(y, oof_non_rounded), 
                              method='Nelder-Mead') 
    assert KappaOPtimizer.success, "Optimization did not converge."
    
    oof_tuned = threshold_Rounder(oof_non_rounded, KappaOPtimizer.x)
    tKappa = quadratic_weighted_kappa(y, oof_tuned)

    print(f"----> || Optimized : {Fore.CYAN}{Style.BRIGHT} {tKappa:.3f}{Style.RESET_ALL}")

    tpm = test_preds.mean(axis=1)
    tpTuned = threshold_Rounder(tpm, KappaOPtimizer.x)
    
    submission = pd.DataFrame({
        'id': sample['id'],
        'sii': tpTuned
    })

    return submission
# Out:
# CPU times: user 3.56 ms, sys: 45 µs, total: 3.6 ms
# Wall time: 2.99 ms

# %%
# %%time
Params_XGB = {
    'learning_rate': 0.046, 
    'max_depth': 12, 
    'min_child_weight': 13, 
    'colsample_bytree': 0.893, 
    'subsample': 0.784, 
    'reg_alpha': 6.596, 
    'reg_lambda': 2.680e-06, 
    'n_estimators': 200,
}

XGB_Model = xgb.XGBRegressor(**Params_XGB)
Submission = TrainML(XGB_Model,test,seed_list)
# Out:
# Training Folds: 100%|██████████| 5/5 [00:36<00:00,  7.38s/it]
# Train : 0.8482
# Validation : 0.3982
# ----> || Optimized :  0.457
# CPU times: user 2min 21s, sys: 508 ms, total: 2min 22s
# Wall time: 37.3 s

# %%
# %%time

LatestParams = {'learning_rate': 0.03755757104848504, 'max_depth': 12, 'num_leaves': 18, 'min_data_in_leaf': 3, 
                'feature_fraction': 0.723690362968002, 'bagging_fraction': 0.688232590484764, 'bagging_freq': 5,
                'lambda_l1': 0.18512987285245963, 'lambda_l2': 0.18435628737334625}

Light = lgb.LGBMRegressor(**LatestParams, verbose=-1, n_estimators=200)

Submission1 = TrainML(Light,test,seed_list)
# Out:
# Training Folds: 100%|██████████| 5/5 [00:13<00:00,  2.77s/it]
# Train : 0.7818
# Validation : 0.3855
# ----> || Optimized :  0.447
# CPU times: user 15.2 s, sys: 214 ms, total: 15.4 s
# Wall time: 14.2 s

# %% [markdown]
# <p style="background-color:#4CAF50; font-family:'Arial', sans-serif; color:#FFFFFF; font-size:120%; text-align:center; border: 2px solid #FFFFFF; border-radius:20px; padding: 15px; box-shadow: 2px 2px 4px #888888;">
#   Submission
# </p>

# %%
print(Submission1['sii'].value_counts())
Submission1.to_csv('submission.csv', index=False)
# Out:
# sii
# 1    9
# 0    8
# 2    3
# Name: count, dtype: int64

# %%
#print(Submission['sii'].value_counts())
#Submission.to_csv('submission.csv', index=False)

# %%
#ensemble = (Submission + Submission1)
#print(ensemble['sii'].value_counts())
#ensemble.to_csv('submission.csv', index=False)
